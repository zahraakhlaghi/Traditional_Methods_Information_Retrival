# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd

# %%
docs = pd.read_csv('dataset/hw1_docs.csv')
docs
# Out:
#        doc_id                                           document
# 0    2p7qrgx0  Since 2007, many cases of fever, thrombocytope...
# 1    25dcnext  BACKGROUND: Respiratory viral (RV) outbreaks i...
# 2    2jq626ye  A novel coronavirus (2019-nCoV) originating in...
# 3    270msv5l  • Several studies suggested Baricitinib as a p...
# 4    14x4uqq7  Evidence from the 2003 SARS epidemic and 2009 ...
# ..        ...                                                ...
# 745  1ebkagvv  OBJECTIVE: To retrospectively analyze the ches...
# 746  80dfqjql  Summary The novel human coronavirus SARS-CoV-2...
# 747  0fzwwluc  Objectives: Patients with novel coronavirus di...
# 748  105q161g  A number of virological, epidemiological and e...
# 749  15rcq4sh  We evaluated a virus-infected cell-based indir...
#
# [750 rows x 2 columns]

# %%
queries = pd.read_csv("dataset/hw1_queries.csv")
queries
# Out:
#     query_id                                              query
# 0          1                     what is the origin of COVID-19
# 1          2  how does the coronavirus respond to changes in...
# 2          3  will SARS-CoV2 infected people develop immunit...
# 3          4                   what causes death from Covid-19?
# 4          5  what drugs have been active against SARS-CoV o...
# 5          6  what types of rapid testing for Covid-19 have ...
# 6          7  are there serological tests that detect antibo...
# 7          8  how has lack of testing availability led to un...
# 8          9                   how has COVID-19 affected Canada
# 9         10  has social distancing had an impact on slowing...
# 10        11  what are the guidelines for triaging patients ...
# 11        12  what are best practices in hospitals and at ho...
# 12        13   what are the transmission routes of coronavirus?
# 13        14  what evidence is there related to COVID-19 sup...
# 14        15  how long can the coronavirus live outside the ...
# 15        16  how long does coronavirus remain stable  on su...
# 16        17  are there any clinical trials available for th...
# 17        18  what are the best masks for preventing infecti...
# 18        19  what type of hand sanitizer is needed to destr...
# 19        20  are patients taking Angiotensin-converting enz...
# 20        21  what are the mortality rates overall and in sp...
# 21        22  are cardiac complications likely in patients w...
# 22        23  what kinds of complications related to COVID-1...
# 23        24  what kinds of complications related to COVID-1...
# 24        25  which biomarkers predict the severe clinical c...
# 25        26         what are the initial symptoms of Covid-19?
# 26        27  what is known about those infected with Covid-...
# 27        28  what evidence is there for the value of hydrox...
# 28        29  which SARS-CoV-2 proteins-human proteins inter...
# 29        30  is remdesivir an effective treatment for COVID-19
# 30        31  How does the coronavirus differ from seasonal ...
# 31        32  Does SARS-CoV-2 have any subtypes, and if so w...
# 32        33  What vaccine candidates are being tested for C...
# 33        34  What are the longer-term complications of thos...
# 34        35  What new public datasets are available related...
# 35        36  What is the protein structure of the SARS-CoV-...
# 36        37  What is the result of phylogenetic analysis of...
# 37        38  What is the mechanism of inflammatory response...
# 38        39  What is the mechanism of cytokine storm syndro...
# 39        40  What are the observed mutations in the SARS-Co...
# 40        41  What are the impacts of COVID-19 among African...
# 41        42  Does Vitamin D impact COVID-19 prevention and ...
# 42        43  How has the COVID-19 pandemic impacted violenc...
# 43        44  How much impact do masks have on preventing th...
# 44        45  How has the COVID-19 pandemic impacted mental ...
# 45        46  what evidence is there for dexamethasone as a ...
# 46        47  what are the health outcomes for children who ...
# 47        48  what are the benefits and risks of re-opening ...
# 48        49  do individuals who recover from COVID-19 show ...
# 49        50  what is known about an mRNA vaccine for the SA...

# %%
qrels = pd.read_csv("dataset/hw1_qrels.csv")
qrels
# Out:
#      query_id    doc_id
# 0           1  005b2j4b
# 1           1  0chuwvg6
# 2           1  0t2a5500
# 3           1  0y34yxlb
# 4           1  105q161g
# ..        ...       ...
# 745        50  xhm97wy2
# 746        50  xieqswct
# 747        50  y87tq9wu
# 748        50  ygwdldae
# 749        50  ykzsoafe
#
# [750 rows x 2 columns]

# %%
import re
import nltk  #Natural language processing tool-kit
from nltk.corpus import stopwords

temp = []
snow = nltk.stem.SnowballStemmer('english')
stop = set(stopwords.words('english'))

contractions = {
    "ain't": "am not",
    "aren't": "are not",
    "can't": "can not",
    "can't've": "can not have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how is",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'm": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so as",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what'll've": "what will have",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "when's": "when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where is",
    "where've": "where have",
    "who'll": "who will",
    "who'll've": "who will have",
    "who's": "who is",
    "who've": "who have",
    "why's": "why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you would",
    "you'd've": "you would have",
    "you'll": "you will",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have"
}


def preprocess(doc):
    sentence = doc.lower()  # Converting to lowercase
    cleaner = re.compile('<.*?>')
    sentence = re.sub(cleaner, ' ', sentence)  #Removing HTML tags
    sentence = re.sub(r'[?|!|\'|"|#]', r'', sentence)
    sentence = re.sub(r'[.|,|)|(|\|/]', r' ', sentence)
    sentence = re.sub(r'[^a-zA-Z]', ' ', sentence)

    q_decontracted = []

    for word in sentence.split():
        if word in contractions:
            word = contractions[word]

        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ll", " will")

    sentence = q

    sentence = " ".join([snow.stem(word) for word in sentence.split() if word not in stopwords.words('english')])

    return sentence

# %%
docs['processed_document'] = docs['document'].apply(lambda t: preprocess(t))
docs
# Out:
#        doc_id                                           document  \
# 0    2p7qrgx0  Since 2007, many cases of fever, thrombocytope...
# 1    25dcnext  BACKGROUND: Respiratory viral (RV) outbreaks i...
# 2    2jq626ye  A novel coronavirus (2019-nCoV) originating in...
# 3    270msv5l  • Several studies suggested Baricitinib as a p...
# 4    14x4uqq7  Evidence from the 2003 SARS epidemic and 2009 ...
# ..        ...                                                ...
# 745  1ebkagvv  OBJECTIVE: To retrospectively analyze the ches...
# 746  80dfqjql  Summary The novel human coronavirus SARS-CoV-2...
# 747  0fzwwluc  Objectives: Patients with novel coronavirus di...
# 748  105q161g  A number of virological, epidemiological and e...
# 749  15rcq4sh  We evaluated a virus-infected cell-based indir...
#
#                                     processed_document
# 0    sinc mani case fever thrombocytopenia leukopen...
# 1    background respiratori viral rv outbreak rehab...
# 2    novel coronavirus ncov origin wuhan china pres...
# 3    sever studi suggest baricitinib potenti drug m...
# 4    evid sar epidem h n pandem show face mask effe...
# ..                                                 ...
# 745  object retrospect analyz chest comput tomograp...
# 746  summari novel human coronavirus sar cov becom ...
# 747  object patient novel coronavirus diseas covid ...
# 748  number virolog epidemiolog ethnograph argument...
# 749  evalu virus infect cell base indirect immunofl...
#
# [750 rows x 3 columns]

# %%
queries['processed_query'] = queries['query'].apply(lambda t: preprocess(t))
queries
# Out:
#     query_id                                              query  \
# 0          1                     what is the origin of COVID-19
# 1          2  how does the coronavirus respond to changes in...
# 2          3  will SARS-CoV2 infected people develop immunit...
# 3          4                   what causes death from Covid-19?
# 4          5  what drugs have been active against SARS-CoV o...
# 5          6  what types of rapid testing for Covid-19 have ...
# 6          7  are there serological tests that detect antibo...
# 7          8  how has lack of testing availability led to un...
# 8          9                   how has COVID-19 affected Canada
# 9         10  has social distancing had an impact on slowing...
# 10        11  what are the guidelines for triaging patients ...
# 11        12  what are best practices in hospitals and at ho...
# 12        13   what are the transmission routes of coronavirus?
# 13        14  what evidence is there related to COVID-19 sup...
# 14        15  how long can the coronavirus live outside the ...
# 15        16  how long does coronavirus remain stable  on su...
# 16        17  are there any clinical trials available for th...
# 17        18  what are the best masks for preventing infecti...
# 18        19  what type of hand sanitizer is needed to destr...
# 19        20  are patients taking Angiotensin-converting enz...
# 20        21  what are the mortality rates overall and in sp...
# 21        22  are cardiac complications likely in patients w...
# 22        23  what kinds of complications related to COVID-1...
# 23        24  what kinds of complications related to COVID-1...
# 24        25  which biomarkers predict the severe clinical c...
# 25        26         what are the initial symptoms of Covid-19?
# 26        27  what is known about those infected with Covid-...
# 27        28  what evidence is there for the value of hydrox...
# 28        29  which SARS-CoV-2 proteins-human proteins inter...
# 29        30  is remdesivir an effective treatment for COVID-19
# 30        31  How does the coronavirus differ from seasonal ...
# 31        32  Does SARS-CoV-2 have any subtypes, and if so w...
# 32        33  What vaccine candidates are being tested for C...
# 33        34  What are the longer-term complications of thos...
# 34        35  What new public datasets are available related...
# 35        36  What is the protein structure of the SARS-CoV-...
# 36        37  What is the result of phylogenetic analysis of...
# 37        38  What is the mechanism of inflammatory response...
# 38        39  What is the mechanism of cytokine storm syndro...
# 39        40  What are the observed mutations in the SARS-Co...
# 40        41  What are the impacts of COVID-19 among African...
# 41        42  Does Vitamin D impact COVID-19 prevention and ...
# 42        43  How has the COVID-19 pandemic impacted violenc...
# 43        44  How much impact do masks have on preventing th...
# 44        45  How has the COVID-19 pandemic impacted mental ...
# 45        46  what evidence is there for dexamethasone as a ...
# 46        47  what are the health outcomes for children who ...
# 47        48  what are the benefits and risks of re-opening ...
# 48        49  do individuals who recover from COVID-19 show ...
# 49        50  what is known about an mRNA vaccine for the SA...
#
#                                       processed_query
# 0                                        origin covid
# 1                   coronavirus respond chang weather
# 2   sar cov infect peopl develop immun cross prote...
# 3                                    caus death covid
# 4               drug activ sar cov sar cov anim studi
# 5                       type rapid test covid develop
# 6            serolog test detect antibodi coronavirus
# 7    lack test avail led underreport true incid covid
# 8                                 covid affect canada
# 9             social distanc impact slow spread covid
# 10          guidelin triag patient infect coronavirus
# 11        best practic hospit home maintain quarantin
# 12                         transmiss rout coronavirus
# 13                    evid relat covid super spreader
# 14                  long coronavirus live outsid bodi
# 15               long coronavirus remain stabl surfac
# 16                     clinic trial avail coronavirus
# 17                     best mask prevent infect covid
# 18                 type hand sanit need destroy covid
# 19  patient take angiotensin convert enzym inhibit...
# 20                    mortal rate overal specif popul
# 21                 cardiac complic like patient covid
# 22          kind complic relat covid associ hypertens
# 23             kind complic relat covid associ diabet
# 24     biomark predict sever clinic cours ncov infect
# 25                                initi symptom covid
# 26                      known infect covid asymptomat
# 27            evid valu hydroxychloroquin treat covid
# 28  sar cov protein human protein interact indic p...
# 29                  remdesivir effect treatment covid
# 30                      coronavirus differ season flu
# 31                                     sar cov subtyp
# 32                           vaccin candid test covid
# 33                    longer term complic recov covid
# 34               new public dataset avail relat covid
# 35                     protein structur sar cov spike
# 36    result phylogenet analysi sar cov genom sequenc
# 37  mechan inflammatori respons pathogenesi covid ...
# 38                 mechan cytokin storm syndrom covid
# 39       observ mutat sar cov genom often mutat occur
# 40  impact covid among african american differ res...
# 41             vitamin impact covid prevent treatment
# 42  covid pandem impact violenc societi includ vio...
# 43              much impact mask prevent spread covid
# 44                  covid pandem impact mental health
# 45                  evid dexamethason treatment covid
# 46              health outcom children contract covid
# 47        benefit risk open school midst covid pandem
# 48  individu recov covid show suffici immun respon...
# 49                    known mrna vaccin sar cov virus

# %% [markdown]
#     This part builds an inverted index as an hash table (dictionary)
#     where the keys are the terms and the values are ordered lists of
#     docIDs containing the term.

# %%
from collections import defaultdict

index = defaultdict(set)

for ind in docs.index:

    doc_id = docs['doc_id'][ind]
    terms = docs['processed_document'][ind].split()

    for term in terms:
        index[term].add(doc_id)

index
# Out:
# defaultdict(set,
#             {'sinc': {'00qk10im',
#               '019rcbpg',
#               '02azobp3',
#               '02ejyglj',
#               '02qvv8le',
#               '08ftq7hl',
#               '08vsaov7',
#               '0chuwvg6',
#               '0cq5ee1i',
#               '0eqn7m73',
#               '0eucsyej',
#               '0fkupng6',
#               '0ie6tkgm',
#               '0jfwzfge',
#               '0k5m2tmt',
#               '0l1jubg5',
#               '0o05oskr',
#               '0oxo2awm',
#               '0qn4c5t3',
#               '0r8vo1fa',
#               '0t974igx',
#               '0udqwhx8',
#               '0uvzy48c',
#               '0w8i7l7v',
#               '0x4332i8',
#               '0xc276mq',
#               '0xkz36bj',
#               '0ylislv9',
#               '10l12wgu',
#               '11sl17ap',
#               '12o4zey2',
#               '12sbikmx',
#               '17wpnfao',
#               '1aqtqaod',
#               '1ay60wzs',
#               '1c3fpazy',
#               '1cfwj5uq',
#               '1k3d3o2q',
#               '1kzy7rts',
#               '1m6poddy',
#               '1mfize6h',
#               '1pnc889f',
#               '1r8dhqi5',
#               '1ru15s5a',
#               '1sxhza50',
#               '1taf0245',
#               '1v6ci0ni',
#               '1xrg631b',
#               '1ym07y0w',
#               '1yrcbm7e',
#               '1zti6kin',
#               '284qn075',
#               '28enxc5h',
#               '28sgnyh1',
#               '2a7t447d',
#               '2bz9u8k0',
#               '2cvp8wch',
#               '2o3dvi2d',
#               '2p7qrgx0',
#               '2w3bx6p8',
#               '2yblpbwm',
#               '3v4sedfo',
#               '3xfhjddg',
#               '4cmeglm3',
#               '4eak8e8l',
#               '4sxsyr6k',
#               '5pv11lfo',
#               '5sz2md8t',
#               '6q0y3ewu',
#               '76pcefik',
#               '96j45f1a',
#               'br3ahtf7',
#               'mgsaoz3j',
#               'xieqswct'},
#              'mani': {'01mo6yo9',
#               '01s9vj74',
#               '02n30zc5',
#               '03pd9jtn',
#               '07amiydg',
#               '07l9hqsr',
#               '0ai8chbu',
#               '0beno5o5',
#               '0dznbrs1',
#               '0einpgeu',
#               '0gier0lu',
#               '0hxan9rw',
#               '0ie6tkgm',
#               '0j6no7ix',
#               '0k6r5q1t',
#               '0klg8yvs',
#               '0mructd7',
#               '0o79m08j',
#               '0oma7hdu',
#               '0rdq6g0b',
#               '0twnkv93',
#               '0y34yxlb',
#               '0z8x6v04',
#               '106q6ae0',
#               '10ecm4wi',
#               '11es4w0u',
#               '11sl17ap',
#               '12o4zey2',
#               '154amdh9',
#               '15jmiqrc',
#               '17a70tu9',
#               '1a6d8urj',
#               '1abupl36',
#               '1c1k0p93',
#               '1c3fpazy',
#               '1cew6vn5',
#               '1d4gf7kr',
#               '1dq91x2r',
#               '1fmouoal',
#               '1gswvgya',
#               '1jeat383',
#               '1lisdjpm',
#               '1lx84td6',
#               '1mfize6h',
#               '1qah31ev',
#               '1rw80tde',
#               '1uwdekl3',
#               '1vc1h7kt',
#               '1z5fky0d',
#               '1zhsqtwj',
#               '21fhsooy',
#               '22y5ewq6',
#               '24m4rh9w',
#               '25qqr3vt',
#               '25va2cvt',
#               '262bcl7h',
#               '27z0z409',
#               '28enxc5h',
#               '28sgnyh1',
#               '2a8kpr8y',
#               '2cvp8wch',
#               '2cvpzlu1',
#               '2l42genc',
#               '2p7qrgx0',
#               '2sdqehyw',
#               '37821r59',
#               '40bpu5nk',
#               '431ksdno',
#               '4ea77hqx',
#               '4giwnrbw',
#               '4jjuwc9r',
#               '4nv1kedt',
#               '54mxjzfc',
#               '5hei9fac',
#               '5w70yhvy',
#               '75c4wvhq',
#               '7kovd82v',
#               '90qq0xsw',
#               '9nbj3ckb',
#               'v0m90h3n',
#               'y87tq9wu'},
#              'case': {'00rq0ggi',
#               '019rcbpg',
#               '01f5mvsc',
#               '01goni72',
#               '01mo6yo9',
#               '02bk8vtk',
#               '02ejyglj',
#               '02n30zc5',
#               '02qvv8le',
#               '03s9spbi',
#               '040w9ba1',
#               '04esvfhp',
#               '04rbtmmi',
#               '04zbbyii',
#               '05w8tv8x',
#               '06x0cei2',
#               '07amiydg',
#               '08zf7161',
#               '09vuwtzr',
#               '0a49okho',
#               '0agldesf',
#               '0av6gx7r',
#               '0b14ocyt',
#               '0bbzo9cp',
#               '0beno5o5',
#               '0bm3bimr',
#               '0d6o5w8z',
#               '0deyspy2',
#               '0dgmfeak',
#               '0eaotgnf',
#               '0einpgeu',
#               '0eqn7m73',
#               '0fkupng6',
#               '0fzwwluc',
#               '0gikppdh',
#               '0gmtnkbh',
#               '0gxxuyln',
#               '0hgj2hcp',
#               '0hki5u13',
#               '0hxan9rw',
#               '0hxwkzvy',
#               '0i6qoc53',
#               '0ie6tkgm',
#               '0jfwzfge',
#               '0k5m2tmt',
#               '0k6oqklv',
#               '0k6r5q1t',
#               '0kexilld',
#               '0klg8yvs',
#               '0l4pec0z',
#               '0m5mc320',
#               '0mien60n',
#               '0mx8gpap',
#               '0nwmoua3',
#               '0nyj1sbm',
#               '0o05oskr',
#               '0o79m08j',
#               '0ojayw16',
#               '0oma7hdu',
#               '0phtilhi',
#               '0pknmeip',
#               '0r62kx2q',
#               '0r8vo1fa',
#               '0rbgbsj8',
#               '0t974igx',
#               '0twnkv93',
#               '0u00nhf2',
#               '0udqwhx8',
#               '0vg4mnxc',
#               '0w7tq79d',
#               '0w8i7l7v',
#               '0wh7x410',
#               '0x4b2f6e',
#               '0xa2njzy',
#               '0y2kq6zg',
#               '0y34yxlb',
#               '0y62eqdx',
#               '0yaqhphd',
#               '0ylislv9',
#               '0ymzuhi0',
#               '0yumc7em',
#               '1046cs2b',
#               '106q6ae0',
#               '10l12wgu',
#               '10n2u1b1',
#               '10phij1x',
#               '10v7kfcd',
#               '10vxz4ug',
#               '1109fcvc',
#               '1152vpv5',
#               '11es4w0u',
#               '11pcdnlw',
#               '12dimncv',
#               '12sbikmx',
#               '147yc66p',
#               '14ftgh6k',
#               '14twsem0',
#               '14w3ygss',
#               '15rcq4sh',
#               '15slu3kk',
#               '15zj660u',
#               '16crg3k8',
#               '16t5rs6j',
#               '17oac3bg',
#               '17wpnfao',
#               '17zue2xp',
#               '1915kvwk',
#               '1993o0eo',
#               '1abp6oom',
#               '1abupl36',
#               '1aqtqaod',
#               '1ay60wzs',
#               '1box6noa',
#               '1bxt21za',
#               '1c3fpazy',
#               '1cew6vn5',
#               '1da6ackj',
#               '1dq91x2r',
#               '1e49nyb5',
#               '1ecnco9q',
#               '1ei79lna',
#               '1exyjhj0',
#               '1hfxju5f',
#               '1hwcp09t',
#               '1idyb9cg',
#               '1ir2ptuj',
#               '1jf2zz5q',
#               '1k3d3o2q',
#               '1llox90t',
#               '1lq1n4hd',
#               '1m6poddy',
#               '1mbn5cc5',
#               '1mfize6h',
#               '1mmqfp7g',
#               '1mxgmhik',
#               '1n3t23ag',
#               '1nczw70h',
#               '1nkr3mwm',
#               '1oauxryz',
#               '1ot9wfnb',
#               '1pnc889f',
#               '1pwlctxb',
#               '1qah31ev',
#               '1qk77fqo',
#               '1r8dhqi5',
#               '1roqno6p',
#               '1taf0245',
#               '1tb38v4k',
#               '1tkevj8v',
#               '1vc1h7kt',
#               '1waejlwb',
#               '1wkyxnov',
#               '1xj2sg4y',
#               '1xnfkbxu',
#               '1xrg631b',
#               '1yf5y06o',
#               '1ym07y0w',
#               '1yrcbm7e',
#               '1z0ympt6',
#               '1zti6kin',
#               '21fnyxw7',
#               '223v2obv',
#               '22y5ewq6',
#               '23yi8so0',
#               '24et9foe',
#               '273ppceg',
#               '27z0z409',
#               '281oiwuz',
#               '284qn075',
#               '28enxc5h',
#               '2990fbda',
#               '2a7t447d',
#               '2b9udaic',
#               '2bjn0fmr',
#               '2bz9u8k0',
#               '2c114qbp',
#               '2cvp8wch',
#               '2d04geu3',
#               '2d21mbr5',
#               '2efyfmvm',
#               '2ehuuvnx',
#               '2g4m0dy7',
#               '2g6jxi5k',
#               '2g78afj2',
#               '2gb9pzy0',
#               '2i3iv0sz',
#               '2iokkog5',
#               '2j4z5rp8',
#               '2llnlr8a',
#               '2nmdyf7b',
#               '2o3dvi2d',
#               '2ohq74mq',
#               '2p7qrgx0',
#               '2pmpspuj',
#               '2ptc7g5a',
#               '2qpcot6p',
#               '2qthdldg',
#               '2sdqehyw',
#               '2t4fsfy9',
#               '2ui36lvl',
#               '2umm65yq',
#               '2w3bx6p8',
#               '2wb007gf',
#               '2xflheth',
#               '2zkesall',
#               '32gw2ug3',
#               '344hgezd',
#               '34ytd87a',
#               '37katpp3',
#               '3ayfmpzx',
#               '3cr5x88g',
#               '3i8k3bo5',
#               '3mmo1x2n',
#               '3trr8d0u',
#               '3v4sedfo',
#               '3zmq7nd5',
#               '411qyubx',
#               '42t0zriz',
#               '4832h1ht',
#               '4cmeglm3',
#               '4dnzjeyp',
#               '4eak8e8l',
#               '4i32jv9i',
#               '4oa0gsos',
#               '4pij0x9q',
#               '4q72jj2h',
#               '4r0t3q7j',
#               '4rutnzbu',
#               '4sxsyr6k',
#               '4vfk99f5',
#               '4yjyqjpe',
#               '55f2cno3',
#               '58sc6xgq',
#               '5bdoz5am',
#               '5c6lwhno',
#               '5hei9fac',
#               '5pv11lfo',
#               '5unh2a3f',
#               '5w70yhvy',
#               '6ar58ea6',
#               '6ikziooc',
#               '73b2rcn1',
#               '7agyp81c',
#               '7g12596l',
#               '7g7fkmuv',
#               '7ihtyiox',
#               '7kovd82v',
#               '8jhwamfv',
#               '8stdci8h',
#               '90q4py0j',
#               '9e4txeck',
#               '9ffvdgon',
#               '9xmksj06',
#               'be7hez61',
#               'kf7yz3oz',
#               'lj8t52yl',
#               'mgsaoz3j',
#               'u35rryzi',
#               'vk8s1f23',
#               'wzdgizoo',
#               'xa314x4p',
#               'ykzsoafe'},
#              'fever': {'02mmdgjk',
#               '03vy3uaj',
#               '04esvfhp',
#               '09vuwtzr',
#               '0av6gx7r',
#               '0dav52vr',
#               '0deyspy2',
#               '0em5sf3g',
#               '0hgj2hcp',
#               '0hie9nw7',
#               '0hrmk77p',
#               '0kexilld',
#               '0l1jubg5',
#               '0lsniwyv',
#               '0rbgbsj8',
#               '0vnewsci',
#               '0ylislv9',
#               '0ymzuhi0',
#               '1558088w',
#               '17oac3bg',
#               '17zue2xp',
#               '18q23z8l',
#               '1993o0eo',
#               '1aqtqaod',
#               '1cfwj5uq',
#               '1elytjos',
#               '1frc4zya',
#               '1n3t23ag',
#               '1n5ej08f',
#               '1qjmktdl',
#               '1qk77fqo',
#               '1zfr32pc',
#               '21fnyxw7',
#               '25ezat4g',
#               '2990fbda',
#               '2b9udaic',
#               '2c114qbp',
#               '2nmdyf7b',
#               '2p7qrgx0',
#               '34ytd87a',
#               '45bwzuqn',
#               '5hei9fac',
#               '935r7w01',
#               'be7hez61'},
#              'thrombocytopenia': {'10phij1x', '2p7qrgx0'},
#              'leukopenia': {'2p7qrgx0'},
#              'syndrom': {'005b2j4b',
#               '00fmeepz',
#               '00qk10im',
#               '00z7x46i',
#               '01mo6yo9',
#               '02ejyglj',
#               '02mmdgjk',
#               '02n30zc5',
#               '02o93wlh',
#               '0376d6vf',
#               '03vy3uaj',
#               '040w9ba1',
#               '043w3zgy',
#               '04awj06g',
#               '04esvfhp',
#               '04rbtmmi',
#               '06x0cei2',
#               '076qek8o',
#               '07ryzlt0',
#               '07z1deqg',
#               '08ftq7hl',
#               '08zf7161',
#               '09qp0sts',
#               '0a5fccio',
#               '0agldesf',
#               '0av6gx7r',
#               '0b14ocyt',
#               '0bz4micv',
#               '0c412wq5',
#               '0ctlde8w',
#               '0d6p4z2z',
#               '0dav52vr',
#               '0eucsyej',
#               '0fgquau3',
#               '0gmtnkbh',
#               '0hie9nw7',
#               '0i5dcbzz',
#               '0ifsyct7',
#               '0ikvdwkz',
#               '0j5828ah',
#               '0k6oqklv',
#               '0lsniwyv',
#               '0macgbcn',
#               '0nwmoua3',
#               '0nyj1sbm',
#               '0p0q6a3i',
#               '0phcscz8',
#               '0phtilhi',
#               '0pknmeip',
#               '0qn4c5t3',
#               '0r8vo1fa',
#               '0rbgbsj8',
#               '0slywdik',
#               '0t28p4g6',
#               '0t2a5500',
#               '0tdt0wej',
#               '0twnkv93',
#               '0u7j42i2',
#               '0x4332i8',
#               '0y62eqdx',
#               '10qpje4d',
#               '10vxz4ug',
#               '11sxecb3',
#               '12o4zey2',
#               '12q9jjbb',
#               '12sbikmx',
#               '12to67c4',
#               '13tc3loo',
#               '14pgap3r',
#               '15rcq4sh',
#               '17kk4w0m',
#               '17oac3bg',
#               '17zue2xp',
#               '18q23z8l',
#               '194kf3xs',
#               '19h27op5',
#               '1a6guo10',
#               '1a75s5l0',
#               '1abp6oom',
#               '1aknmk3h',
#               '1ay60wzs',
#               '1bmu7tis',
#               '1bxt21za',
#               '1c1k0p93',
#               '1d4gf7kr',
#               '1dbeh8q7',
#               '1ecnco9q',
#               '1ei79lna',
#               '1hwcp09t',
#               '1i5arpf8',
#               '1k3j6f79',
#               '1l33w015',
#               '1mbn5cc5',
#               '1mcl5yf1',
#               '1mjaycee',
#               '1mjl7f8w',
#               '1mmqfp7g',
#               '1nerinn3',
#               '1nkr3mwm',
#               '1no1zaty',
#               '1nxfh9yt',
#               '1q39v843',
#               '1qk77fqo',
#               '1ru15s5a',
#               '1tb38v4k',
#               '1tkevj8v',
#               '1udn20wo',
#               '1untezgg',
#               '1v8wwn0d',
#               '1vgb2mk0',
#               '1wkyxnov',
#               '1xkl3mof',
#               '1xnfkbxu',
#               '1xrg631b',
#               '1z6l12ks',
#               '1zfr32pc',
#               '1zhsqtwj',
#               '21fnyxw7',
#               '22fc1qly',
#               '24yavi1w',
#               '281oiwuz',
#               '2b9udaic',
#               '2brbgvqo',
#               '2c114qbp',
#               '2c8c2gns',
#               '2d21mbr5',
#               '2e4gz2bo',
#               '2ehuuvnx',
#               '2i3iv0sz',
#               '2j4z5rp8',
#               '2jeb1vcs',
#               '2lxs9laj',
#               '2nvk7glh',
#               '2o3dvi2d',
#               '2p7qrgx0',
#               '2t2it6f5',
#               '2wb007gf',
#               '2xcit185',
#               '2zaxn6tq',
#               '3d8up3zo',
#               '3eu9umx5',
#               '3pd1lre7',
#               '3trr8d0u',
#               '3xfhjddg',
#               '3zmq7nd5',
#               '46aln4tk',
#               '4azlivaa',
#               '4b45gh77',
#               '4cmeglm3',
#               '4e2j89uy',
#               '4ywrzyse',
#               '582h1w0h',
#               '58tj4csz',
#               '5c6lwhno',
#               '5hei9fac',
#               '5pv11lfo',
#               '5sz2md8t',
#               '5x30jj1s',
#               '61eeykj1',
#               '6cm1vp7h',
#               '6q0y3ewu',
#               '75apu1m4',
#               '7g12596l',
#               '7g7fkmuv',
#               '7xqmuoye',
#               '80dfqjql',
#               '8jhwamfv',
#               '8r6u3e3i',
#               '96j45f1a',
#               'b0nkhsvv',
#               'be7hez61',
#               'br3ahtf7',
#               'c1n994j6',
#               'g1j8wk11',
#               'h0q93in1',
#               'xieqswct',
#               'y87tq9wu',
#               'ygwdldae',
#               'ykzsoafe'},
#              'ftls': {'2p7qrgx0'},
#              'emerg': {'00fmeepz',
#               '00qk10im',
#               '00z7x46i',
#               '02n30zc5',
#               '041cf99j',
#               '04esvfhp',
#               '04zbbyii',
#               '05nnihst',
#               '05w8tv8x',
#               '06x0cei2',
#               '06yilajc',
#               '08ftq7hl',
#               '08p8ns2d',
#               '08vsaov7',
#               '08zf7161',
#               '09gzchv0',
#               '0beno5o5',
#               '0bm3bimr',
#               '0brmwon4',
#               '0bz4micv',
#               '0chuwvg6',
#               '0ctlde8w',
#               '0cxhxbsv',
#               '0dgmfeak',
#               '0dwlaafj',
#               '0ec1cu8q',
#               '0eqn7m73',
#               '0gier0lu',
#               '0gmtnkbh',
#               '0hgj2hcp',
#               '0hie9nw7',
#               '0hxan9rw',
#               '0i6qoc53',
#               '0jv5mnnl',
#               '0k5m2tmt',
#               '0kexilld',
#               '0klg8yvs',
#               '0macgbcn',
#               '0mn4b0fp',
#               '0mn4jua2',
#               '0nq62oao',
#               '0ojayw16',
#               '0phtilhi',
#               '0pknmeip',
#               '0rdq6g0b',
#               '0sy3j2oc',
#               '0twnkv93',
#               '0x4332i8',
#               '0xa2njzy',
#               '105q161g',
#               '10ecm4wi',
#               '10phij1x',
#               '11edrkav',
#               '11hi1jel',
#               '12sbikmx',
#               '13hperkz',
#               '13l2cbg1',
#               '14pgap3r',
#               '14twsem0',
#               '15ow3n9z',
#               '17kk4w0m',
#               '17oac3bg',
#               '17q4g88y',
#               '17wpnfao',
#               '18yzwa2g',
#               '1993o0eo',
#               '1cc9ig04',
#               '1cew6vn5',
#               '1d4gf7kr',
#               '1dbeh8q7',
#               '1dq91x2r',
#               '1ei79lna',
#               '1fmouoal',
#               '1h5a4bit',
#               '1hfxju5f',
#               '1huoe4dp',
#               '1ir19s25',
#               '1ir2ptuj',
#               '1k5h662u',
#               '1mjaycee',
#               '1na13h2u',
#               '1nkpmw5a',
#               '1no1zaty',
#               '1q39v843',
#               '1q9bhwpb',
#               '1r8dhqi5',
#               '1rphpf62',
#               '1s0hhx71',
#               '1tb38v4k',
#               '1tkevj8v',
#               '1wj23s9k',
#               '1y78dfsl',
#               '1yrcbm7e',
#               '1z6l12ks',
#               '1zezzai5',
#               '2071y2x8',
#               '22fc1qly',
#               '24yavi1w',
#               '285ud8gh',
#               '28enxc5h',
#               '2a8kpr8y',
#               '2brbgvqo',
#               '2c114qbp',
#               '2djys8ky',
#               '2g4m0dy7',
#               '2j4z5rp8',
#               '2lxs9laj',
#               '2p7qrgx0',
#               '2qpcot6p',
#               '2sdqehyw',
#               '2w3bx6p8',
#               '2x54egpf',
#               '2zaxn6tq',
#               '3kxn8l2e',
#               '3r66vrv0',
#               '3v4sedfo',
#               '46aln4tk',
#               '4832h1ht',
#               '4cmeglm3',
#               '4ea77hqx',
#               '4sxsyr6k',
#               '4ywrzyse',
#               '5hei9fac',
#               '5kcl80sj',
#               '6cm1vp7h',
#               '6xvbk2f1',
#               '73b2rcn1',
#               '76pcefik',
#               '7g7fkmuv',
#               '92ijxah4',
#               '96j45f1a',
#               'c1n994j6',
#               'd6v5mkj7',
#               'g1j8wk11',
#               'kf7yz3oz',
#               'mgsaoz3j',
#               'q77da2y3',
#               'u35rryzi',
#               'v0m90h3n',
#               'x6hln4wk',
#               'xieqswct',
#               'ygwdldae',
#               'ykzsoafe'},
#              'henan': {'2p7qrgx0'},
#              'provinc': {'02ejyglj',
#               '03pd9jtn',
#               '04rbtmmi',
#               '05nnihst',
#               '09vuwtzr',
#               '0a5fccio',
#               '0brmwon4',
#               '0bz4micv',
#               '0dav52vr',
#               '0ie6tkgm',
#               '0is1vyhy',
#               '0l1jubg5',
#               '0lvzfcw3',
#               '0x4332i8',
#               '0xa2njzy',
#               '0ylislv9',
#               '0ymzuhi0',
#               '106q6ae0',
#               '11es4w0u',
#               '12sbikmx',
#               '15slu3kk',
#               '1abp6oom',
#               '1aqtqaod',
#               '1e49nyb5',
#               '1k5q1u5z',
#               '1nxfh9yt',
#               '1vkz0b0o',
#               '284qn075',
#               '2d21mbr5',
#               '2nmdyf7b',
#               '2p7qrgx0',
#               '344hgezd',
#               '37egvx5k',
#               '4cmeglm3',
#               '4i32jv9i',
#               '6apsd91c',
#               '7ihtyiox',
#               '7x77e4m5',
#               '90q4py0j',
#               '9ffvdgon'},
#              'china': {'00fmeepz',
#               '00qk10im',
#               '02ejyglj',
#               '02qvv8le',
#               '03pd9jtn',
#               '040w9ba1',
#               '04rbtmmi',
#               '05nnihst',
#               '06yilajc',
#               '08ftq7hl',
#               '08mjfs83',
#               '08zf7161',
#               '0bm3bimr',
#               '0brmwon4',
#               '0bz4micv',
#               '0c412wq5',
#               '0cxhxbsv',
#               '0d6p4z2z',
#               '0dav52vr',
#               '0em5sf3g',
#               '0fgquau3',
#               '0gmtnkbh',
#               '0hgj2hcp',
#               '0is1vyhy',
#               '0j5828ah',
#               '0k5m2tmt',
#               '0k6oqklv',
#               '0kexilld',
#               '0l1jubg5',
#               '0lfjktq1',
#               '0lsniwyv',
#               '0lyxvex0',
#               '0pi8qur0',
#               '0t28p4g6',
#               '0twnkv93',
#               '0uvzy48c',
#               '0x4332i8',
#               '0xa2njzy',
#               '0y2kq6zg',
#               '0y62eqdx',
#               '0ylislv9',
#               '10n2u1b1',
#               '10v7kfcd',
#               '10vxz4ug',
#               '11edrkav',
#               '12o4zey2',
#               '12sbikmx',
#               '146matzr',
#               '14w3ygss',
#               '15ow3n9z',
#               '17q4g88y',
#               '17wpnfao',
#               '18crkfzj',
#               '1915kvwk',
#               '1993o0eo',
#               '1abp6oom',
#               '1aknmk3h',
#               '1aqtqaod',
#               '1ay60wzs',
#               '1d4gf7kr',
#               '1dkkwt7h',
#               '1dq91x2r',
#               '1huoe4dp',
#               '1hwcp09t',
#               '1jf2zz5q',
#               '1k5h662u',
#               '1k5q1u5z',
#               '1kzy7rts',
#               '1mfize6h',
#               '1mjaycee',
#               '1n3t23ag',
#               '1nerinn3',
#               '1nxfh9yt',
#               '1pnc889f',
#               '1pwlctxb',
#               '1r8dhqi5',
#               '1rcsqyff',
#               '1s0exznp',
#               '1vkz0b0o',
#               '1wj23s9k',
#               '1xnfkbxu',
#               '1yrcbm7e',
#               '22fc1qly',
#               '22y5ewq6',
#               '248de4cj',
#               '24yavi1w',
#               '25va2cvt',
#               '262bcl7h',
#               '27z0z409',
#               '284qn075',
#               '28sgnyh1',
#               '2brbgvqo',
#               '2cvp8wch',
#               '2ehuuvnx',
#               '2jq626ye',
#               '2jv7xkfn',
#               '2lxs9laj',
#               '2nftsv4f',
#               '2p7qrgx0',
#               '2qpcot6p',
#               '2ui36lvl',
#               '2uvibr2j',
#               '2w3bx6p8',
#               '2yblpbwm',
#               '32gw2ug3',
#               '33j9m3ke',
#               '37egvx5k',
#               '3d8up3zo',
#               '3mmo1x2n',
#               '3r66vrv0',
#               '3v1bid02',
#               '3v4sedfo',
#               '4cmeglm3',
#               '4eak8e8l',
#               '4el6qq3n',
#               '4i32jv9i',
#               '4oa0gsos',
#               '4r0t3q7j',
#               '4yjyqjpe',
#               '55f2cno3',
#               '59prqbb3',
#               '61eeykj1',
#               '6cm1vp7h',
#               '7g7fkmuv',
#               '7ihtyiox',
#               '90q4py0j',
#               'be7hez61',
#               'cccqcfgq',
#               'xa314x4p',
#               'xeq0dq6u'},
#              'patient': {'00fmeepz',
#               '00qk10im',
#               '019rcbpg',
#               '01es0zv4',
#               '01s9vj74',
#               '02azobp3',
#               '02ejyglj',
#               '02n30zc5',
#               '0376d6vf',
#               '03pd9jtn',
#               '040w9ba1',
#               '04esvfhp',
#               '04h53wjz',
#               '05djnz4p',
#               '05nnihst',
#               '05vb2ib8',
#               '05zmldvj',
#               '063hs3u1',
#               '06gbt9t0',
#               '06x0cei2',
#               '06yilajc',
#               '073wsuap',
#               '07amiydg',
#               '07ryzlt0',
#               '08ftq7hl',
#               '08mjfs83',
#               '08p8ns2d',
#               '08siqoqc',
#               '08xf2ye5',
#               '08zf7161',
#               '09qp0sts',
#               '09vuwtzr',
#               '0a5fccio',
#               '0a624nez',
#               '0agldesf',
#               '0ai8chbu',
#               '0b14ocyt',
#               '0bbzo9cp',
#               '0beno5o5',
#               '0bk2t0h0',
#               '0brmwon4',
#               '0c412wq5',
#               '0d6p4z2z',
#               '0dav52vr',
#               '0deyspy2',
#               '0dgmfeak',
#               '0dp28rsd',
#               '0dwlaafj',
#               '0e0sttvw',
#               '0ec1cu8q',
#               '0eucsyej',
#               '0fgquau3',
#               '0fzwwluc',
#               '0gier0lu',
#               '0gikppdh',
#               '0gmtnkbh',
#               '0hgj2hcp',
#               '0hie9nw7',
#               '0hki5u13',
#               '0i6qoc53',
#               '0ifsyct7',
#               '0j1jdd1w',
#               '0j5828ah',
#               '0j6no7ix',
#               '0jfwzfge',
#               '0k5j5h7p',
#               '0k6oqklv',
#               '0k6r5q1t',
#               '0kexilld',
#               '0kthumgi',
#               '0l1jubg5',
#               '0lfjktq1',
#               '0m3svdmy',
#               '0m5mc320',
#               '0mn4b0fp',
#               '0nwmoua3',
#               '0nyj1sbm',
#               '0o92zije',
#               '0oak9ggm',
#               '0ou5f158',
#               '0oxo2awm',
#               '0phcscz8',
#               '0pro23px',
#               '0qur0isb',
#               '0rbgbsj8',
#               '0sy3j2oc',
#               '0t974igx',
#               '0tdfvlqd',
#               '0tdt0wej',
#               '0tsefy6p',
#               '0tte9rf6',
#               '0tto8b0k',
#               '0twnkv93',
#               '0u00nhf2',
#               '0udqwhx8',
#               '0uvzy48c',
#               '0ux8nwn7',
#               '0vg4mnxc',
#               '0vlh67jw',
#               '0vnewsci',
#               '0w7tq79d',
#               '0x4332i8',
#               '0x4b2f6e',
#               '0y2kq6zg',
#               '0yaqhphd',
#               '0ylislv9',
#               '0ymzuhi0',
#               '0yq5ror7',
#               '0yumc7em',
#               '1046cs2b',
#               '106q6ae0',
#               '10l12wgu',
#               '10phij1x',
#               '10qpje4d',
#               '10v7kfcd',
#               '10vxz4ug',
#               '11es4w0u',
#               '11sxecb3',
#               '12ienbdx',
#               '12q9jjbb',
#               '12yk278d',
#               '146matzr',
#               '14twsem0',
#               '1510mzmy',
#               '15jmiqrc',
#               '15zj660u',
#               '16fzqskz',
#               '178f21u7',
#               '17kk4w0m',
#               '17oac3bg',
#               '17zue2xp',
#               '18yzwa2g',
#               '194kf3xs',
#               '195h4ofw',
#               '1993o0eo',
#               '19h27op5',
#               '1a6guo10',
#               '1aqtqaod',
#               '1bmu7tis',
#               '1box6noa',
#               '1cew6vn5',
#               '1cfwj5uq',
#               '1cpk2p9g',
#               '1d4gf7kr',
#               '1dbeh8q7',
#               '1dq91x2r',
#               '1ebkagvv',
#               '1ecnco9q',
#               '1ei79lna',
#               '1eiw7bxh',
#               '1fjb6b8e',
#               '1frc4zya',
#               '1gswvgya',
#               '1hfxju5f',
#               '1hvihwkz',
#               '1i5arpf8',
#               '1i6kvuof',
#               '1idyb9cg',
#               '1jeh7hke',
#               '1k3j6f79',
#               '1k5q1u5z',
#               '1lfm24wz',
#               '1lj4ydmm',
#               '1m6poddy',
#               '1mbn5cc5',
#               '1mcl5yf1',
#               '1mfize6h',
#               '1mjl7f8w',
#               '1n5ej08f',
#               '1n6d1gco',
#               '1na13h2u',
#               '1nczw70h',
#               '1nerinn3',
#               '1nkpmw5a',
#               '1nkr3mwm',
#               '1nxfh9yt',
#               '1oudnxmt',
#               '1pnc889f',
#               '1pwlctxb',
#               '1q39v843',
#               '1qjmktdl',
#               '1qk77fqo',
#               '1rphpf62',
#               '1s0exznp',
#               '1sxhza50',
#               '1untezgg',
#               '1v6ci0ni',
#               '1vc1h7kt',
#               '1wj23s9k',
#               '1wkyxnov',
#               '1xj2sg4y',
#               '1xkl3mof',
#               '1xrg631b',
#               '1y78dfsl',
#               '1z0ympt6',
#               '1z5fky0d',
#               '1zezzai5',
#               '1zfr32pc',
#               '1zhsqtwj',
#               '1zti6kin',
#               '2071y2x8',
#               '20hk99h4',
#               '20w0w53s',
#               '223v2obv',
#               '24m4rh9w',
#               '2530zdeq',
#               '25dcnext',
#               '25ezat4g',
#               '262bcl7h',
#               '269kzfd7',
#               '270msv5l',
#               '27dmsmbu',
#               '27g10f2q',
#               '284qn075',
#               '285ud8gh',
#               '29z5fvyi',
#               '2b9udaic',
#               '2bjn0fmr',
#               '2boqg3tz',
#               '2brbgvqo',
#               '2bz9u8k0',
#               '2c114qbp',
#               '2c8c2gns',
#               '2efyfmvm',
#               '2ehuuvnx',
#               '2eterq28',
#               '2g5gi1du',
#               '2gb9pzy0',
#               '2gzo81cz',
#               '2i3iv0sz',
#               '2j3kdvva',
#               '2jq626ye',
#               '2jv7xkfn',
#               '2lmwnfda',
#               '2nftsv4f',
#               '2nmdyf7b',
#               '2nvk7glh',
#               '2p7qrgx0',
#               '2pmpspuj',
#               '2ptc7g5a',
#               '2s9zd99r',
#               '2wb007gf',
#               '2wnfl4pr',
#               '2xcit185',
#               '2z5ixtk3',
#               '31y378jx',
#               '33j9m3ke',
#               '34v1w16g',
#               '34ytd87a',
#               '380az9lp',
#               '3cr5x88g',
#               '3d8up3zo',
#               '3eu9umx5',
#               '3i8k3bo5',
#               '3kxn8l2e',
#               '3q2jju2u',
#               '3thnu3kk',
#               '3xfhjddg',
#               '3zmq7nd5',
#               '411qyubx',
#               '4178ui2c',
#               '42t0zriz',
#               '45bwzuqn',
#               '46aln4tk',
#               '478wbtfb',
#               '4832h1ht',
#               '4azlivaa',
#               '4b45gh77',
#               '4dnzjeyp',
#               '4ea77hqx',
#               '4frdzp4c',
#               '4g878n13',
#               '4od9gu6y',
#               '4pij0x9q',
#               '4q72jj2h',
#               '4r0t3q7j',
#               '4ud6awrw',
#               '4vfk99f5',
#               '4yjyqjpe',
#               '52c4xhiw',
#               '58sc6xgq',
#               '58tj4csz',
#               '59prqbb3',
#               '5c6lwhno',
#               '5eflvvht',
#               '5fknjzkq',
#               '5hei9fac',
#               '5lhvix51',
#               '5pv11lfo',
#               '5sz2md8t',
#               '5unh2a3f',
#               '5x30jj1s',
#               '61eeykj1',
#               '6cm1vp7h',
#               '6q0y3ewu',
#               '73b2rcn1',
#               '75apu1m4',
#               '75c4wvhq',
#               '76pcefik',
#               '7g12596l',
#               '7g7fkmuv',
#               '7ihtyiox',
#               '7l79ic0v',
#               '7v2hdy8a',
#               '7x77e4m5',
#               '7xqmuoye',
#               '871812f7',
#               '8jhwamfv',
#               '8li6xhbu',
#               '8qtintwl',
#               '8stdci8h',
#               '8wlxkflg',
#               '90q4py0j',
#               '935r7w01',
#               '96j45f1a',
#               '9e4txeck',
#               '9is5vmxu',
#               '9iuesnxo',
#               '9nbj3ckb',
#               '9xmksj06',
#               'br3ahtf7',
#               'c69vfs8q',
#               'oiu80002',
#               'oj4ue0ur',
#               'vk8s1f23',
#               'wzdgizoo'},
#              'report': {'005b2j4b',
#               '006k39tj',
#               '00fmeepz',
#               '00rq0ggi',
#               '019rcbpg',
#               '01d8cqn4',
#               '01es0zv4',
#               '02bk8vtk',
#               '02ejyglj',
#               '02qvv8le',
#               '03pd9jtn',
#               '03vy3uaj',
#               '043w3zgy',
#               '047xpt2c',
#               '04esvfhp',
#               '04zbbyii',
#               '05tszdt7',
#               '06x0cei2',
#               '06y1ihvn',
#               '06yilajc',
#               '07v9qign',
#               '08zf7161',
#               '094lgjnn',
#               '0a5fccio',
#               '0bm3bimr',
#               '0croajal',
#               '0cxhxbsv',
#               '0d6o5w8z',
#               '0dp28rsd',
#               '0einpgeu',
#               '0em5sf3g',
#               '0eucsyej',
#               '0fgquau3',
#               '0g5scezh',
#               '0gikppdh',
#               '0haf57l1',
#               '0hki5u13',
#               '0hrmk77p',
#               '0hxan9rw',
#               '0i6qoc53',
#               '0ie6tkgm',
#               '0j5828ah',
#               '0jfwzfge',
#               '0jv5mnnl',
#               '0k5j5h7p',
#               '0k5m2tmt',
#               '0lyxvex0',
#               '0m5mc320',
#               '0mx8gpap',
#               '0o79m08j',
#               '0o92zije',
#               '0oxo2awm',
#               '0phcscz8',
#               '0qur0isb',
#               '0r0zdpds',
#               '0r62kx2q',
#               '0s11tdgd',
#               '0sy3j2oc',
#               '0t2a5500',
#               '0t974igx',
#               '0tdt0wej',
#               '0tsefy6p',
#               '0twnkv93',
#               '0u7j42i2',
#               '0v5wo0ty',
#               '0vg4mnxc',
#               '0vlzwksu',
#               '0vnewsci',
#               '0xa2njzy',
#               '0xc276mq',
#               '0xqxledk',
#               '0y62eqdx',
#               '0yaqhphd',
#               '0ylislv9',
#               '106q6ae0',
#               '10l12wgu',
#               '10phij1x',
#               '10vxz4ug',
#               '11edrkav',
#               '11hi1jel',
#               '11sl17ap',
#               '12ienbdx',
#               '12q9jjbb',
#               '12to67c4',
#               '13hperkz',
#               '13tc3loo',
#               '14ftgh6k',
#               '14n4szd1',
#               '14twsem0',
#               '1558088w',
#               '16t5rs6j',
#               '17kk4w0m',
#               '17q4g88y',
#               '17wpnfao',
#               '17zue2xp',
#               '18q23z8l',
#               '19h2i631',
#               '1a6guo10',
#               '1abupl36',
#               '1aknmk3h',
#               '1aqtqaod',
#               '1box6noa',
#               '1dkkwt7h',
#               '1ei79lna',
#               '1eiw7bxh',
#               '1gswvgya',
#               '1huoe4dp',
#               '1hwcp09t',
#               '1idyb9cg',
#               '1jf2zz5q',
#               '1jg46veg',
#               '1k3j6f79',
#               '1k5q1u5z',
#               '1kzy7rts',
#               '1lfm24wz',
#               '1llox90t',
#               '1lq1n4hd',
#               '1lugzjbv',
#               '1mbn5cc5',
#               '1n3t23ag',
#               '1no1zaty',
#               '1nxfh9yt',
#               '1oauxryz',
#               '1q71gjwt',
#               '1qk77fqo',
#               '1rphpf62',
#               '1s0exznp',
#               '1s0hhx71',
#               '1taf0245',
#               '1x5bhtx7',
#               '1xnfkbxu',
#               '1xrg631b',
#               '1y78dfsl',
#               '1z5fky0d',
#               '1z6l12ks',
#               '21fnyxw7',
#               '223v2obv',
#               '22fc1qly',
#               '248de4cj',
#               '24m4rh9w',
#               '25dcnext',
#               '25va2cvt',
#               '26f514ay',
#               '270msv5l',
#               '27dmsmbu',
#               '27z0z409',
#               '284qn075',
#               '28enxc5h',
#               '2990fbda',
#               '2a7t447d',
#               '2a8kpr8y',
#               '2b9udaic',
#               '2bz9u8k0',
#               '2cvp8wch',
#               '2djys8ky',
#               '2ehuuvnx',
#               '2fknxsf1',
#               '2i3iv0sz',
#               '2l4xxu3v',
#               '2lebavgm',
#               '2llnlr8a',
#               '2lxs9laj',
#               '2nmdyf7b',
#               '2nruf2g7',
#               '2nvk7glh',
#               '2ohq74mq',
#               '2p7qrgx0',
#               '2sdqehyw',
#               '2uvibr2j',
#               '2w3bx6p8',
#               '2wb007gf',
#               '2y452utz',
#               '2yblpbwm',
#               '2zaxn6tq',
#               '2zkesall',
#               '2zkrbjqe',
#               '32gw2ug3',
#               '34v1w16g',
#               '37821r59',
#               '37katpp3',
#               '380az9lp',
#               '3ayfmpzx',
#               '3d8up3zo',
#               '3eu9umx5',
#               '3kxn8l2e',
#               '3nl3js2x',
#               '3pribklz',
#               '3thnu3kk',
#               '3zmq7nd5',
#               '411qyubx',
#               '42o9qs47',
#               '42t0zriz',
#               '478wbtfb',
#               '4832h1ht',
#               '4dnzjeyp',
#               '4el6qq3n',
#               '4g878n13',
#               '4i32jv9i',
#               '4jjuwc9r',
#               '4pij0x9q',
#               '4q72jj2h',
#               '4rutnzbu',
#               '4ud6awrw',
#               '4vfk99f5',
#               '54mxjzfc',
#               '55f2cno3',
#               '582h1w0h',
#               '58sc6xgq',
#               '58tj4csz',
#               '59prqbb3',
#               '5bdoz5am',
#               '5fknjzkq',
#               '5pv11lfo',
#               '5x30jj1s',
#               '6cm1vp7h',
#               '73b2rcn1',
#               '7agyp81c',
#               '7g12596l',
#               '7ihtyiox',
#               '8jhwamfv',
#               '90q4py0j',
#               '90qq0xsw',
#               '9e4txeck',
#               '9nbj3ckb',
#               'be7hez61',
#               'd63miqjd',
#               'kf7yz3oz',
#               't8250da4',
#               'u35rryzi',
#               'ygwdldae'},
#              'tick': {'2p7qrgx0'},
#              'bite': {'2p7qrgx0'},
#              'suggest': {'00rq0ggi',
#               '01q4pu9k',
#               '01s9vj74',
#               '033phqmd',
#               '03pd9jtn',
#               '03vy3uaj',
#               '04rbtmmi',
#               '05vb2ib8',
#               '063hs3u1',
#               '06yilajc',
#               '07ryzlt0',
#               '08vsaov7',
#               '09qp0sts',
#               '0a49okho',
#               '0chuwvg6',
#               '0croajal',
#               '0d6p4z2z',
#               '0dbuo39v',
#               '0en2sl3q',
#               '0gier0lu',
#               '0gmtnkbh',
#               '0j5828ah',
#               '0lvzfcw3',
#               '0m5mc320',
#               '0mn4b0fp',
#               '0nwmoua3',
#               '0qur0isb',
#               '0rbgbsj8',
#               '0sy3j2oc',
#               '0t28p4g6',
#               '0t2a5500',
#               '0tdt0wej',
#               '0u7j42i2',
#               '0v5wo0ty',
#               '0vlzwksu',
#               '0vnewsci',
#               '0x4b2f6e',
#               '0xqxledk',
#               '0yq5ror7',
#               '105q161g',
#               '10ecm4wi',
#               '13l2cbg1',
#               '146matzr',
#               '147yc66p',
#               '1510mzmy',
#               '15jmiqrc',
#               '16t5rs6j',
#               '17oac3bg',
#               '17q4g88y',
#               '17zue2xp',
#               '18q23z8l',
#               '1a6guo10',
#               '1abp6oom',
#               '1bmu7tis',
#               '1dq91x2r',
#               '1fmouoal',
#               '1fxrmuzl',
#               '1gswvgya',
#               '1huoe4dp',
#               '1iio41wn',
#               '1jf2zz5q',
#               '1k3d3o2q',
#               '1lq1n4hd',
#               '1m6poddy',
#               '1mbn5cc5',
#               '1mcl5yf1',
#               '1mxgmhik',
#               '1nerinn3',
#               '1sq2uvur',
#               '1vc1h7kt',
#               '1xrg631b',
#               '1y78dfsl',
#               '1z0ympt6',
#               '1z6l12ks',
#               '1zhsqtwj',
#               '20w0w53s',
#               '21fnyxw7',
#               '223v2obv',
#               '22y5ewq6',
#               '24m4rh9w',
#               '262bcl7h',
#               '270msv5l',
#               '2brbgvqo',
#               '2c8c2gns',
#               '2cvp8wch',
#               '2d04geu3',
#               '2g4m0dy7',
#               '2nvk7glh',
#               '2o3dvi2d',
#               '2p7qrgx0',
#               '2sdqehyw',
#               '2zkesall',
#               '34ytd87a',
#               '37821r59',
#               '3cm44rbz',
#               '3d8up3zo',
#               '3eu9umx5',
#               '3iy2lp8q',
#               '3r66vrv0',
#               '3trr8d0u',
#               '3v1bid02',
#               '411qyubx',
#               '4178ui2c',
#               '46aln4tk',
#               '49640zjj',
#               '4b45gh77',
#               '4oa0gsos',
#               '4ud6awrw',
#               '52c4xhiw',
#               '58sc6xgq',
#               '59prqbb3',
#               '5fknjzkq',
#               '5lhvix51',
#               '5pv11lfo',
#               '6ar58ea6',
#               '6ikziooc',
#               '73b2rcn1',
#               '76pcefik',
#               '7g12596l',
#               '7l79ic0v',
#               '7v2hdy8a',
#               '7x77e4m5',
#               '871812f7',
#               '8jhwamfv',
#               '8r6u3e3i',
#               '9e4txeck',
#               '9iuesnxo',
#               'btzrfs6g',
#               'c69vfs8q',
#               'cccqcfgq',
#               'mgsaoz3j',
#               'x6hln4wk',
#               'xeq0dq6u',
#               'ykzsoafe'},
#              'infect': {'00fmeepz',
#               '00qk10im',
#               '00rq0ggi',
#               '019rcbpg',
#               '01eyo422',
#               '01goni72',
#               '01mo6yo9',
#               '01q4pu9k',
#               '01s9vj74',
#               '01xdd8zf',
#               '02ejyglj',
#               '02n30zc5',
#               '033phqmd',
#               '0376d6vf',
#               '03pd9jtn',
#               '03s9spbi',
#               '03vy3uaj',
#               '040w9ba1',
#               '04esvfhp',
#               '04h53wjz',
#               '04pp0o74',
#               '05djnz4p',
#               '05nnihst',
#               '05vb2ib8',
#               '05w8tv8x',
#               '05zmldvj',
#               '061zxvxc',
#               '06vc2y9y',
#               '06x0cei2',
#               '06yilajc',
#               '07l9hqsr',
#               '08ftq7hl',
#               '08p8ns2d',
#               '08vsaov7',
#               '08zf7161',
#               '094lgjnn',
#               '09vuwtzr',
#               '0a49okho',
#               '0a5fccio',
#               '0a8sz7zb',
#               '0agldesf',
#               '0ai8chbu',
#               '0av6gx7r',
#               '0bbzo9cp',
#               '0beno5o5',
#               '0bk2t0h0',
#               '0bm3bimr',
#               '0brmwon4',
#               '0c412wq5',
#               '0cq5ee1i',
#               '0croajal',
#               '0cvh83zu',
#               '0dd6alkp',
#               '0deyspy2',
#               '0e0sttvw',
#               '0e1wmy41',
#               '0en2sl3q',
#               '0eucsyej',
#               '0gier0lu',
#               '0gmtnkbh',
#               '0haf57l1',
#               '0hgj2hcp',
#               '0hie9nw7',
#               '0hki5u13',
#               '0hrmk77p',
#               '0i6qoc53',
#               '0ie6tkgm',
#               '0is1vyhy',
#               '0j1jdd1w',
#               '0j5828ah',
#               '0jfwzfge',
#               '0k6r5q1t',
#               '0kexilld',
#               '0klg8yvs',
#               '0kthumgi',
#               '0l1jubg5',
#               '0lsniwyv',
#               '0lyxvex0',
#               '0m5mc320',
#               '0mien60n',
#               '0mn4b0fp',
#               '0mructd7',
#               '0mx8gpap',
#               '0n8x3i0v',
#               '0nwmoua3',
#               '0nyj1sbm',
#               '0o79m08j',
#               '0o92zije',
#               '0oak9ggm',
#               '0oxo2awm',
#               '0phcscz8',
#               '0phtilhi',
#               '0pknmeip',
#               '0qn4c5t3',
#               '0qur0isb',
#               '0r0zdpds',
#               '0r8vo1fa',
#               '0s11tdgd',
#               '0slywdik',
#               '0t28p4g6',
#               '0tdt0wej',
#               '0te5ybjv',
#               '0tsefy6p',
#               '0twnkv93',
#               '0u7j42i2',
#               '0uvzy48c',
#               '0v1appqr',
#               '0vlzwksu',
#               '0vnewsci',
#               '0w7tq79d',
#               '0w8i7l7v',
#               '0x4332i8',
#               '0x4b2f6e',
#               '0xkz36bj',
#               '0yaqhphd',
#               '0ylislv9',
#               '0ymzuhi0',
#               '0yq5ror7',
#               '0yumc7em',
#               '0z8x6v04',
#               '1046cs2b',
#               '10ecm4wi',
#               '10n2u1b1',
#               '10phij1x',
#               '10vxz4ug',
#               '1109fcvc',
#               '1152vpv5',
#               '11hi1jel',
#               '11pcdnlw',
#               '11sxecb3',
#               '12q9jjbb',
#               '12yk278d',
#               '147yc66p',
#               '14n4szd1',
#               '14twsem0',
#               '14w3ygss',
#               '1558088w',
#               '15jmiqrc',
#               '15rcq4sh',
#               '15slu3kk',
#               '15zj660u',
#               '16fzqskz',
#               '178f21u7',
#               '17kk4w0m',
#               '17lvpyre',
#               '17oac3bg',
#               '18crkfzj',
#               '18fbtlfg',
#               '18q23z8l',
#               '18yzwa2g',
#               '194kf3xs',
#               '19h27op5',
#               '19h2i631',
#               '1a6d8urj',
#               '1a6guo10',
#               '1a75s5l0',
#               '1abp6oom',
#               '1abupl36',
#               '1aknmk3h',
#               '1aqtqaod',
#               '1ay60wzs',
#               '1b3pigtl',
#               '1b7viy5o',
#               '1bhv9snq',
#               '1bmu7tis',
#               '1c1k0p93',
#               '1cew6vn5',
#               '1cpk2p9g',
#               '1d4gf7kr',
#               '1da6ackj',
#               '1dq91x2r',
#               '1e49nyb5',
#               '1ei79lna',
#               '1eiw7bxh',
#               '1elytjos',
#               '1fp4ck88',
#               '1frc4zya',
#               '1fxrmuzl',
#               '1gswvgya',
#               '1hfnv35j',
#               '1hvihwkz',
#               '1hwcp09t',
#               '1iio41wn',
#               '1ir19s25',
#               '1jeat383',
#               '1jf2zz5q',
#               '1k3j6f79',
#               '1k5h662u',
# ...
#               '1a6d8urj',
#               '1lisdjpm',
#               '1lq1n4hd',
#               '1mxgmhik',
#               '1xj2sg4y',
#               '2071y2x8',
#               '21fhsooy',
#               '24et9foe',
#               '27g10f2q',
#               '2bz9u8k0',
#               '2gzo81cz',
#               '2lmwnfda',
#               '4avkvrxo',
#               '4dnzjeyp',
#               '555e3ndo',
#               '5fknjzkq',
#               '6ar58ea6',
#               '7xqmuoye'},
#              'concomit': {'06gbt9t0',
#               '14twsem0',
#               '16fzqskz',
#               '1xkl3mof',
#               '285ud8gh',
#               '2jv7xkfn',
#               '2sdqehyw',
#               '7xqmuoye'},
#              'interstiti': {'08zf7161', '46aln4tk', '7xqmuoye'},
#              'taken': {'02azobp3',
#               '0fbmelx0',
#               '0gmtnkbh',
#               '0ikvdwkz',
#               '0oxo2awm',
#               '0tdt0wej',
#               '0x90yubt',
#               '0y34yxlb',
#               '105q161g',
#               '1fmouoal',
#               '1fxrmuzl',
#               '1k3d3o2q',
#               '1nkpmw5a',
#               '1wkyxnov',
#               '262bcl7h',
#               '28sgnyh1',
#               '2s9zd99r',
#               '2uvibr2j',
#               '2wb007gf',
#               '2y452utz',
#               '2z5ixtk3',
#               '3mmo1x2n',
#               '3v4sedfo',
#               '4bio5jp5',
#               '4cmeglm3',
#               '4ishl6bj',
#               '73b2rcn1',
#               '7ihtyiox',
#               '7v2hdy8a',
#               '8stdci8h',
#               '9xmksj06',
#               'c69vfs8q',
#               'y87tq9wu'},
#              'live': {'02bk8vtk',
#               '05zmldvj',
#               '08vsaov7',
#               '0ctlde8w',
#               '0eaotgnf',
#               '0g5scezh',
#               '0l1jubg5',
#               '0vlzwksu',
#               '0x90yubt',
#               '12q9jjbb',
#               '12yk278d',
#               '14ftgh6k',
#               '1d4gf7kr',
#               '1dkkwt7h',
#               '1n6d1gco',
#               '1nxfh9yt',
#               '1v6ci0ni',
#               '1z0ympt6',
#               '2zkesall',
#               '4jjuwc9r',
#               'xieqswct',
#               'y87tq9wu',
#               'ykzsoafe'},
#              'corona': {'01f5mvsc',
#               '08vsaov7',
#               '0hki5u13',
#               '0lsniwyv',
#               '0lvzfcw3',
#               '0lyxvex0',
#               '0macgbcn',
#               '0o79m08j',
#               '16fzqskz',
#               '1aknmk3h',
#               '1cew6vn5',
#               '1ir19s25',
#               '1q71gjwt',
#               '2bjn0fmr',
#               '40bpu5nk',
#               '4bio5jp5',
#               '4ishl6bj',
#               '5sz2md8t',
#               '6q0y3ewu',
#               '871812f7',
#               '90qq0xsw',
#               '9iuesnxo',
#               'br3ahtf7',
#               'y87tq9wu'},
#              'date': {'00rq0ggi',
#               '01mo6yo9',
#               '05w8tv8x',
#               '0bk2t0h0',
#               '0chuwvg6',
#               '0gmtnkbh',
#               '0k5m2tmt',
#               '0k6r5q1t',
#               '0lsniwyv',
#               '0mructd7',
#               '0sy3j2oc',
#               '0tto8b0k',
#               '0u7j42i2',
#               '0udqwhx8',
#               '1046cs2b',
#               '10l12wgu',
#               '10n2u1b1',
#               '11hi1jel',
#               '12o4zey2',
#               '17oac3bg',
#               '17wpnfao',
#               '1c1k0p93',
#               '1lq1n4hd',
#               '1mxgmhik',
#               '1no1zaty',
#               '1qah31ev',
#               '1sq2uvur',
#               '1vkz0b0o',
#               '1zhsqtwj',
#               '20w0w53s',
#               '21fnyxw7',
#               '23yi8so0',
#               '273ppceg',
#               '2cvp8wch',
#               '2ehuuvnx',
#               '2gb9pzy0',
#               '2i3iv0sz',
#               '2j3kdvva',
#               '2s9zd99r',
#               '2uvibr2j',
#               '2w3bx6p8',
#               '2wb007gf',
#               '4ea77hqx',
#               '4el6qq3n',
#               '6ar58ea6',
#               'd6v5mkj7',
#               'x6hln4wk',
#               'y87tq9wu'},
#              'usa': {'0ctlde8w',
#               '0g5scezh',
#               '0k6oqklv',
#               '0twnkv93',
#               '11edrkav',
#               '146matzr',
#               '14w3ygss',
#               '1bhv9snq',
#               '1da6ackj',
#               '1exyjhj0',
#               '1lq1n4hd',
#               '1mxgmhik',
#               '2j3kdvva',
#               '2zaxn6tq',
#               '32gw2ug3',
#               '33j9m3ke',
#               '3mmo1x2n',
#               '6ar58ea6',
#               'be7hez61',
#               'xeq0dq6u',
#               'y87tq9wu'},
#              'itali': {'01d8cqn4',
#               '04rbtmmi',
#               '0jv5mnnl',
#               '0lfjktq1',
#               '0twnkv93',
#               '0v1appqr',
#               '0yaqhphd',
#               '14w3ygss',
#               '1510mzmy',
#               '1da6ackj',
#               '1dbeh8q7',
#               '1exyjhj0',
#               '1k5q1u5z',
#               '1mbn5cc5',
#               '1qah31ev',
#               '1r8dhqi5',
#               '1wj23s9k',
#               '1xkl3mof',
#               '1ym07y0w',
#               '2cvp8wch',
#               '32gw2ug3',
#               '36l1q4dp',
#               '3mmo1x2n',
#               '4bio5jp5',
#               '4ishl6bj',
#               '4pij0x9q',
#               '4r0t3q7j',
#               '75apu1m4',
#               'y87tq9wu'},
#              'spain': {'04rbtmmi',
#               '0twnkv93',
#               '0x4b2f6e',
#               '0yaqhphd',
#               '10l12wgu',
#               '14w3ygss',
#               '1510mzmy',
#               '1h5a4bit',
#               '1r8dhqi5',
#               '2s9zd99r',
#               '3mmo1x2n',
#               '5eflvvht',
#               'y87tq9wu'},
#              'franc': {'04rbtmmi',
#               '0e1wmy41',
#               '0l4pec0z',
#               '0twnkv93',
#               '0x4b2f6e',
#               '14w3ygss',
#               '1da6ackj',
#               '1h5a4bit',
#               '1n5ej08f',
#               '1r8dhqi5',
#               '32gw2ug3',
#               '3mmo1x2n',
#               'y87tq9wu'},
#              'russia': {'04rbtmmi',
#               '0b8250y7',
#               '0twnkv93',
#               '1r8dhqi5',
#               '32gw2ug3',
#               'y87tq9wu'},
#              'uk': {'0hxwkzvy',
#               '0twnkv93',
#               '11edrkav',
#               '11hi1jel',
#               '14w3ygss',
#               '1da6ackj',
#               '1ei79lna',
#               '1uwdekl3',
#               '223v2obv',
#               '2i3iv0sz',
#               '2zaxn6tq',
#               '32gw2ug3',
#               '4sxsyr6k',
#               'y87tq9wu'},
#              'hit': {'047xpt2c',
#               '0c412wq5',
#               '10ucu0lt',
#               '1mmqfp7g',
#               '1ot9wfnb',
#               '1wj23s9k',
#               'y87tq9wu'},
#              'hardest': {'1wj23s9k', 'y87tq9wu'},
#              'rise': {'02n30zc5',
#               '03fir7ct',
#               '09gzchv0',
#               '0ikvdwkz',
#               '0k5m2tmt',
#               '0t974igx',
#               '0twnkv93',
#               '147yc66p',
#               '14w3ygss',
#               '15rcq4sh',
#               '17wpnfao',
#               '1k3d3o2q',
#               '1r8dhqi5',
#               '1zfr32pc',
#               '2bz9u8k0',
#               '2iokkog5',
#               '7t0nkt44',
#               'bhkmax7s',
#               'y87tq9wu'},
#              'nation': {'00rq0ggi',
#               '040w9ba1',
#               '041cf99j',
#               '07l9hqsr',
#               '0e1wmy41',
#               '0j5828ah',
#               '0k5j5h7p',
#               '0ojayw16',
#               '0rdq6g0b',
#               '0x4332i8',
#               '1abupl36',
#               '1b3pigtl',
#               '1dkkwt7h',
#               '1dq91x2r',
#               '1ir2ptuj',
#               '1na13h2u',
#               '1nxfh9yt',
#               '1s0hhx71',
#               '2071y2x8',
#               '223v2obv',
#               '26f514ay',
#               '281oiwuz',
#               '284qn075',
#               '2d04geu3',
#               '2f7wqamp',
#               '2g4m0dy7',
#               '2umm65yq',
#               '2wb007gf',
#               '2zaxn6tq',
#               '2zkesall',
#               '3kxn8l2e',
#               '3mmo1x2n',
#               '42bqujvj',
#               '42t0zriz',
#               '4bio5jp5',
#               '4cmeglm3',
#               '4ea77hqx',
#               '4ishl6bj',
#               '4r0t3q7j',
#               '555e3ndo',
#               '5pv11lfo',
#               '61eeykj1',
#               '7t0nkt44',
#               'bhkmax7s',
#               'cccqcfgq',
#               'd63miqjd',
#               'y87tq9wu'},
#              'flatten': {'01f5mvsc',
#               '0nyj1sbm',
#               '147yc66p',
#               '154amdh9',
#               '1ir2ptuj',
#               'y87tq9wu'},
#              'rate': {'01f5mvsc',
#               '02bk8vtk',
#               '02n30zc5',
#               '03fir7ct',
#               '03s9spbi',
#               '047xpt2c',
#               '05zmldvj',
#               '06vc2y9y',
#               '073wsuap',
#               '08mjfs83',
#               '0999t5x0',
#               '0av6gx7r',
#               '0beno5o5',
#               '0chuwvg6',
#               '0cxhxbsv',
#               '0d6o5w8z',
#               '0dp28rsd',
#               '0ec1cu8q',
#               '0en2sl3q',
#               '0g5scezh',
#               '0gier0lu',
#               '0gikppdh',
#               '0gmtnkbh',
#               '0ie6tkgm',
#               '0ifsyct7',
#               '0is1vyhy',
#               '0jv5mnnl',
#               '0k5j5h7p',
#               '0k5m2tmt',
#               '0k6oqklv',
#               '0kexilld',
#               '0klg8yvs',
#               '0l4pec0z',
#               '0m3svdmy',
#               '0m5mc320',
#               '0mx8gpap',
#               '0o79m08j',
#               '0oak9ggm',
#               '0ojayw16',
#               '0oma7hdu',
#               '0pi8qur0',
#               '0qfoc553',
#               '0s11tdgd',
#               '0tdfvlqd',
#               '0tsefy6p',
#               '0tte9rf6',
#               '0tto8b0k',
#               '0uvzy48c',
#               '0vg4mnxc',
#               '0vlzwksu',
#               '0w8i7l7v',
#               '0x4332i8',
#               '0x4b2f6e',
#               '0xqxledk',
#               '0y34yxlb',
#               '0y62eqdx',
#               '0yaqhphd',
#               '106q6ae0',
#               '10n2u1b1',
#               '1152vpv5',
#               '11hi1jel',
#               '11pcdnlw',
#               '11sl17ap',
#               '146matzr',
#               '14ftgh6k',
#               '14pgap3r',
#               '14twsem0',
#               '14w3ygss',
#               '1510mzmy',
#               '15slu3kk',
#               '17kk4w0m',
#               '17oac3bg',
#               '17q4g88y',
#               '17wpnfao',
#               '194kf3xs',
#               '1abupl36',
#               '1aknmk3h',
#               '1bxt21za',
#               '1c3fpazy',
#               '1cpk2p9g',
#               '1da6ackj',
#               '1fmouoal',
#               '1fxrmuzl',
#               '1h5a4bit',
#               '1hfnv35j',
#               '1hfxju5f',
#               '1huoe4dp',
#               '1ir19s25',
#               '1lisdjpm',
#               '1lq1n4hd',
#               '1mjl7f8w',
#               '1mxgmhik',
#               '1n3t23ag',
#               '1n5ej08f',
#               '1oauxryz',
#               '1pnc889f',
#               '1qjmktdl',
#               '1rcsqyff',
#               '1taf0245',
#               '1xkl3mof',
#               '1ym07y0w',
#               '1yrcbm7e',
#               '1zezzai5',
#               '2071y2x8',
#               '20w0w53s',
#               '21fhsooy',
#               '2530zdeq',
#               '269kzfd7',
#               '273ppceg',
#               '27z0z409',
#               '281oiwuz',
#               '28sgnyh1',
#               '2b9udaic',
#               '2bz9u8k0',
#               '2d04geu3',
#               '2d21mbr5',
#               '2ehuuvnx',
#               '2eterq28',
#               '2fknxsf1',
#               '2g4m0dy7',
#               '2g5gi1du',
#               '2g6jxi5k',
#               '2nftsv4f',
#               '2nvk7glh',
#               '2qpcot6p',
#               '2qthdldg',
#               '2umm65yq',
#               '2zkesall',
#               '344hgezd',
#               '34ytd87a',
#               '3pribklz',
#               '3q2jju2u',
#               '3s2g3o81',
#               '3v1bid02',
#               '3zmq7nd5',
#               '401kxcmi',
#               '41378qru',
#               '4eak8e8l',
#               '4rutnzbu',
#               '5fknjzkq',
#               '5hei9fac',
#               '61eeykj1',
#               '6ar58ea6',
#               '6vln3erl',
#               '7agyp81c',
#               '7kovd82v',
#               '8jhwamfv',
#               '9ffvdgon',
#               'be7hez61',
#               'l7ymcyw7',
#               'x6hln4wk',
#               'y87tq9wu'},
#              'e': {'006k39tj',
#               '00rq0ggi',
#               '02n30zc5',
#               '043w3zgy',
#               '076qek8o',
#               '09gzchv0',
#               '0dd6alkp',
#               '0hie9nw7',
#               '0m5mc320',
#               '0n8x3i0v',
#               '0oma7hdu',
#               '0ou5f158',
#               '0t2a5500',
#               '0vnewsci',
#               '11sl17ap',
#               '146matzr',
#               '14pgap3r',
#               '16t5rs6j',
#               '18yzwa2g',
#               '1a6d8urj',
#               '1a6guo10',
#               '1abupl36',
#               '1b7viy5o',
#               '1cc9ig04',
#               '1fxrmuzl',
#               '1llox90t',
#               '1lx84td6',
#               '1n5ej08f',
#               '1sxhza50',
#               '1udn20wo',
#               '1wkyxnov',
#               '28sgnyh1',
#               '2bz9u8k0',
#               '2c114qbp',
#               '2g6jxi5k',
#               '2g78afj2',
#               '2j3kdvva',
#               '2l42genc',
#               '2zaxn6tq',
#               '33j9m3ke',
#               '3cm44rbz',
#               '3eu9umx5',
#               '478wbtfb',
#               '52c4xhiw',
#               '5oe77t20',
#               '7v2hdy8a',
#               'btzrfs6g',
#               'mgsaoz3j',
#               'v0m90h3n',
#               'x6hln4wk',
#               'y87tq9wu'},
#              'hemagglutinin': {'52c4xhiw', 'y87tq9wu'},
#              'esteras': {'y87tq9wu'},
#              'kb': {'y87tq9wu'},
#              'cleav': {'1mjl7f8w', 'xieqswct', 'y87tq9wu'},
#              'polyprotein': {'1a75s5l0', 'y87tq9wu'},
#              'polymeras': {'03vy3uaj',
#               '0bbzo9cp',
#               '0c412wq5',
#               '0gmtnkbh',
#               '0hxan9rw',
#               '0oak9ggm',
#               '0u7j42i2',
#               '0vlh67jw',
#               '0wh7x410',
#               '0x4332i8',
#               '13l2cbg1',
#               '18q23z8l',
#               '1a6d8urj',
#               '1aknmk3h',
#               '1dbeh8q7',
#               '281oiwuz',
#               '2brbgvqo',
#               '2gzo81cz',
#               '2s9zd99r',
#               '2xcit185',
#               '2zaxn6tq',
#               '31y378jx',
#               '3i8k3bo5',
#               '3pribklz',
#               '4azlivaa',
#               '52c4xhiw',
#               '5hei9fac',
#               '5unh2a3f',
#               '7v2hdy8a',
#               'y87tq9wu'},
#              'replic': {'02n30zc5',
#               '033phqmd',
#               '03pd9jtn',
#               '047xpt2c',
#               '05vb2ib8',
#               '08ftq7hl',
#               '08mjfs83',
#               '08zf7161',
#               '0a8sz7zb',
#               '0phtilhi',
#               '0slywdik',
#               '0udqwhx8',
#               '0vg4mnxc',
#               '13l2cbg1',
#               '18yzwa2g',
#               '1a6guo10',
#               '1a75s5l0',
#               '1fp4ck88',
#               '1mmqfp7g',
#               '1no1zaty',
#               '1sxhza50',
#               '2kwfcgz9',
#               '2l4xxu3v',
#               '3d8up3zo',
#               '3iy2lp8q',
#               '59prqbb3',
#               '8jhwamfv',
#               'mgsaoz3j',
#               't8250da4',
#               'xieqswct',
#               'y87tq9wu'},
#              ...})

# %%
from math import log


def RSV_weights(docs, index, pt):
    '''
    This function precomputes the Retrieval Status Value weights
    for each term in the index
    '''
    N = len(docs)
    w = {}

    for term in index.keys():
        df = len(index[term])
        ut = df / N

        w[term] = log((pt * (1 - ut)) / (ut * (1 - pt)))
    return w

# %%
weights7 = RSV_weights(docs, index, 0.7)
weights3 = RSV_weights(docs, index, 0.3)
weights5 = RSV_weights(docs, index, 0.5)

# %%
def RSV_doc_query(doc, query, weights):
    vocab_doc = doc.split()
    vocab_query = query.split()
    score = 0

    for word in vocab_query:
        if word in vocab_doc:
            score = score + weights[word]

    return score

# %%
def compute_full_bim(queries, docs,weights):
    result = {}
    
    for q_ind in queries.index:
        
        q_id = queries['query_id'][q_ind]
        q_doc = queries['processed_query'][q_ind]
        result[q_id] = []
        
        for d_ind in docs.index:
            
            d_id = docs['doc_id'][d_ind]
            result[q_id].append((d_id, RSV_doc_query(q_doc,docs['processed_document'][d_ind],weights)))
            
    return result

# %%
res3 = compute_full_bim(queries,docs,weights3)
res5 = compute_full_bim(queries,docs,weights5)
res7 = compute_full_bim(queries,docs,weights7)

# %%
def precision_at_k(gold, retrieved, k):

    sum_precision_at_k = 0
    count_q = 0
    for q in retrieved:

        top_ten = (sorted(retrieved[q], key=lambda item: item[1], reverse=True)[
                   :10])

        gold_qs = list(gold.loc[gold['query_id'] ==q].doc_id)

        if len(gold_qs) != 0:
            count_q = count_q + 1
        else:
            continue

        sum_correct = 0
        for idx, (result_id, result_text) in enumerate(top_ten):
            if result_id in gold_qs:
                sum_correct = sum_correct + 1
            if idx == k - 1:
                sum_precision_at_k = sum_precision_at_k + (sum_correct / k)
                break

    return sum_precision_at_k / count_q

# %%
def mean_average_precision(gold, retrieved):
    
    sum_average_precision = 0
    count_q = 0
    for q in retrieved:

        top_ten = (sorted(retrieved[q], key=lambda item: item[1], reverse=True)[
                   :10])
        gold_qs = list(gold.loc[gold['query_id'] ==q].doc_id)

        if len(gold_qs) != 0:
            count_q = count_q + 1
        else:
            continue

        sum_precision = 0
        sum_correct = 0

        for idx, (result_id, result_text) in enumerate(top_ten):
            if result_id in gold_qs:
                sum_correct = sum_correct + 1
                sum_precision = sum_precision + (sum_correct / (idx + 1))
        if sum_correct != 0:
            sum_average_precision = sum_average_precision + \
                (sum_precision / sum_correct)

    return sum_average_precision / count_q

# %%
def mean_reciprocal_rank(gold, retrieved):

    sum_reciprocal_rank = 0
    count_q = 0
    for q in retrieved:

        # get top ten values from retrieved dictionary for every query
        top_ten = (
            sorted(retrieved[q], key=lambda item: item[1], reverse=True)[:10])

        # get gold data for every query from gold dictionary
        gold_qs = list(gold.loc[gold['query_id'] ==q].doc_id)

        # ignore queries that don't have any gold data with is_duplicate set to 1
        if len(gold_qs) != 0:
            count_q = count_q + 1
        else:
            continue

        reciprocal_rank = 0
        # find the first relevant retrieved doc and compute reciprocal rank and add it to sum
        for idx, (result_id, result_text) in enumerate(top_ten):
            if result_id in gold_qs:
                reciprocal_rank = 1 / (idx + 1)
                sum_reciprocal_rank = sum_reciprocal_rank + reciprocal_rank
                break

    # avarage of reciprocal ranks
    return sum_reciprocal_rank / count_q

# %%
def result(res,t):
    mrr = mean_reciprocal_rank(qrels, res)
    map = mean_average_precision(qrels, res)
    p_at_5 = precision_at_k(qrels, res, 5)
    p_at_10 = precision_at_k(qrels, res, 10)
    print("pt = {} -> MRR:{} --- MAP:{} --- P@5:{} --- P@10:{}\n".format(t,mrr, map, p_at_5, p_at_10))

# %%
result(res3,0.3)
result(res5,0.5)
result(res7,0.7)
# Out:
# pt = 0.3 -> MRR:0.8036666666666666 --- MAP:0.6982617315444696 --- P@5:0.56 --- P@10:0.46199999999999997
#
# pt = 0.5 -> MRR:0.8589999999999999 --- MAP:0.7632948696145125 --- P@5:0.6480000000000001 --- P@10:0.516
#
# pt = 0.7 -> MRR:0.7872142857142856 --- MAP:0.712228341521794 --- P@5:0.5880000000000003 --- P@10:0.486
